# %%
import glob
import pandas as pd

# %%
#This is the ridership data (smaller csv files)
bike_ridership_data = pd.concat([pd.read_csv(f) for f in glob.glob('data/bike_membership/*.csv')], ignore_index = True)

# %%
bike_ridership_data.count()
# Out:
# Date                                                  90
# Trips over the past 24-hours (midnight to 11:59pm)    90
# Miles traveled today (midnight to 11:59 pm)           90
# Total Annual Members (All Time)                       90
# 24-Hour Passes Purchased (midnight to 11:59 pm)       90
# 3-Day Passes Purchased (midnight to 11:59 pm)         90
# dtype: int64

# %%
bike_ridership_data.head(50)
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    1/1/2018                                               5499
# 1    1/2/2018                                              18818
# 2    1/3/2018                                              24299
# 3    1/4/2018                                               1922
# 4    1/5/2018                                               4972
# 5    1/6/2018                                               4294
# 6    1/7/2018                                               5640
# 7    1/8/2018                                              15820
# 8    1/9/2018                                              25090
# 9   1/10/2018                                              28252
# 10  1/11/2018                                              33961
# 11  1/12/2018                                              22252
# 12  1/13/2018                                              17758
# ...

# %%
bike_ridership_data.tail(50)
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 40  2/10/2018                                              16323
# 41  2/11/2018                                               8809
# 42  2/12/2018                                              35138
# 43  2/13/2018                                              35189
# 44  2/14/2018                                              39591
# 45  2/15/2018                                              44193
# 46  2/16/2018                                              29191
# 47  2/17/2018                                              17921
# 48  2/18/2018                                              21537
# 49  2/19/2018                                              25677
# 50  2/20/2018                                              44478
# 51  2/21/2018                                              53110
# 52  2/22/2018                                              27010
# ...

# %%
#This is the trip data(bigger csv files)
bike_trip_data = pd.concat([pd.read_csv(f) for f in glob.glob('data/bike_trip/*.csv')], ignore_index = True)

# %%
bike_trip_data.count()
# Out:
# tripduration               2538780
# starttime                  2538780
# stoptime                   2538780
# start station id           2538780
# start station name         2538780
# start station latitude     2538780
# start station longitude    2538780
# end station id             2538780
# end station name           2538780
# end station latitude       2538780
# end station longitude      2538780
# bikeid                     2538780
# usertype                   2538780
# birth year                 2538780
# gender                     2538780
# dtype: int64

# %%
bike_trip_data.head(50)
# Out:
#     tripduration                 starttime                  stoptime  \
# 0            970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1            723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2            496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3            306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4            306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
# 5           1602  2018-01-01 21:31:54.1920  2018-01-01 21:58:36.3530
# 6            722  2018-01-02 07:54:53.6460  2018-01-02 08:06:55.8720
# 7            434  2018-01-02 08:06:14.3310  2018-01-02 08:13:28.7670
# 8            366  2018-01-02 08:10:15.2550  2018-01-02 08:16:21.8960
# 9            324  2018-01-02 08:13:30.8960  2018-01-02 08:18:55.1200
# 10          1155  2018-01-02 09:15:29.9050  2018-01-02 09:34:45.0200
# 11          1200  2018-01-02 10:23:18.8800  2018-01-02 10:43:18.9110
# 12           732  2018-01-02 11:52:37.5540  2018-01-02 12:04:49.8800
# ...

# %%
bike_trip_data.tail(50)
# Out:
#          tripduration                 starttime                  stoptime  \
# 2538730           645  2018-03-31 14:32:11.0390  2018-03-31 14:42:56.6340
# 2538731           693  2018-03-31 14:32:18.3380  2018-03-31 14:43:51.9300
# 2538732           179  2018-03-31 14:42:23.6050  2018-03-31 14:45:22.7180
# 2538733           155  2018-03-31 14:42:55.3050  2018-03-31 14:45:31.0140
# 2538734           151  2018-03-31 14:42:59.9070  2018-03-31 14:45:31.8960
# 2538735          1068  2018-03-31 14:45:46.4730  2018-03-31 15:03:34.9070
# 2538736           546  2018-03-31 14:48:59.2530  2018-03-31 14:58:06.1580
# 2538737          1184  2018-03-31 14:56:53.2080  2018-03-31 15:16:37.3400
# 2538738          1133  2018-03-31 14:57:13.3800  2018-03-31 15:16:06.9750
# 2538739          1901  2018-03-31 15:16:11.8060  2018-03-31 15:47:52.9790
# 2538740           385  2018-03-31 15:17:55.7530  2018-03-31 15:24:21.3080
# 2538741           837  2018-03-31 15:26:51.7600  2018-03-31 15:40:49.0170
# ...

# %%
#Ridership dataframe to csv file
bike_ridership_data.to_csv("data/final/bike_membership_data_Q1_2018.csv")

# %%
#trip dataframe to csv file
bike_trip_data.to_csv("data/final/bike_trip_data_Q1_2018.csv")
